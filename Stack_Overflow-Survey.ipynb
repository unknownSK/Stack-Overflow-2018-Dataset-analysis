# %%
import pandas as pd
import matplotlib.pyplot as plt

df1=pd.read_csv('survey_results_public.csv')
df2=pd.read_csv('survey_results_schema.csv')
# Out:
# /home/rinkeshjadav/anaconda3/envs/Demo/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1
# Out:
#        Respondent Hobby OpenSource                       Country  \
# 0               1   Yes         No                         Kenya
# 1               3   Yes        Yes                United Kingdom
# 2               4   Yes        Yes                 United States
# 3               5    No         No                 United States
# 4               7   Yes         No                  South Africa
# 5               8   Yes         No                United Kingdom
# 6               9   Yes        Yes                 United States
# 7              10   Yes        Yes                       Nigeria
# 8              11   Yes        Yes                 United States
# 9              16    No        Yes                         India
# 10             17   Yes         No                         Spain
# 11             18   Yes        Yes                         India
# 12             19   Yes         No                       Croatia
# ...

# %%
df3=df1['Country'].value_counts()

# %%
a=sum(df3[:])-sum(df3[:5])
df3=df3[:5]
df3['Others']=a
df3.plot.bar()

# %%
df1['Student'].value_counts().plot.bar()
plt.xlabel('Are you currently enrolled in a formal, degree-granting college or university program?')
plt.ylabel('Counts')
plt.title('Students Info')
plt.show()

# %%
df1['Employment'].value_counts().plot.bar()
plt.xlabel('Which of the following best describes your current employment status?')
plt.ylabel('Counts')
plt.title('Employment Stats')
plt.show()

# %%
df1['FormalEducation'].value_counts().plot.bar()
plt.xlabel('Which of the following best describes the highest level of formal education that you’ve completed?')
plt.ylabel('Counts')
plt.title('FormalEducation Stats')
plt.show()

# %%
df1['UndergradMajor'].value_counts().plot.bar()
plt.xlabel('You previously indicated that you went to a college or university. Which of the following best describes your main field of study (aka \'major\')')
plt.ylabel('Counts')
plt.title('UndergradMajor Stats')
plt.show()

# %%
df1['CompanySize'].value_counts().plot.bar()
plt.xlabel('Approximately how many people are employed by the company or organization you work for?')
plt.title('CompanySize Stats')
plt.show()

# %%
df1['YearsCoding'].value_counts().plot.bar()
plt.xlabel('Including any education, for how many years have you been coding?')
plt.title('YearsCoding Stats')
plt.show()

# %%
df1['YearsCodingProf'].value_counts().plot.bar()
plt.xlabel('For how many years have you coded professionally (as a part of your work)?')
plt.title('YearsCodingProf Stats')
plt.show()

# %%
df1['JobSatisfaction'].value_counts().plot.bar()
plt.xlabel('How satisfied are you with your current job? If you work more than one job, please answer regarding the one you spend the most hours on.')
plt.title('JobSatisfaction Stats')
plt.show()

# %%
df1['CareerSatisfaction'].value_counts().plot.bar()
plt.xlabel('Overall, how satisfied are you with your career thus far?')
plt.title('CareerSatisfaction Stats')
plt.show()

# %%
df1['HopeFiveYears'].value_counts().plot.bar()
plt.xlabel('Which of the following best describes what you hope to be doing in five years?')
plt.title('HopeFiveYears Stats')
plt.show()

# %%
df1['JobSearchStatus'].value_counts().plot.bar()
plt.xlabel('Which of the following best describes your current job-seeking status?')
plt.title('JobSearchStatus Stats')
plt.show()

# %%
df1['LastNewJob'].value_counts().plot.bar()
plt.xlabel('When was the last time that you took a job with a new employer?')
plt.title('LastNewJob Stats')
plt.show()

# %%
df1['Gender'].value_counts().plot.bar()
plt.title('Gender Stats')
plt.show()

# %%
df5=df1['RaceEthnicity'].value_counts()
a=sum(df5[:])-sum(df5[:5])
df5=df5[:5]
df5['Others']=a
df5.plot.bar()
#plt.xlabel('When was the last time that you took a job with a new employer?')
plt.title('RaceEthnicity Stats')
plt.show()

# %%
df1['Age'].value_counts().plot.bar()
#plt.xlabel('When was the last time that you took a job with a new employer?')
plt.title('Age Stats')
plt.show()

# %%
df1['SurveyTooLong'].value_counts().plot.bar()
plt.xlabel('How do you feel about the length of the survey that you just completed?')
plt.title('SurveyTooLong Stats')
plt.show()

# %%
df1['SurveyEasy'].value_counts().plot.bar()
plt.xlabel('How easy or difficult was this survey to complete?')
plt.title('SurveyEasy Stats')
plt.show()

# %%
df1['WakeTime'].value_counts().plot.bar()
plt.xlabel('On days when you work, what time do you typically wake up?')
plt.title('WakeTime Stats')
plt.show()

# %%
df1['HoursComputer'].value_counts().plot.bar()
plt.xlabel('On a typical day, how much time do you spend on a desktop or laptop computer?')
plt.title('HoursComputer Stats')
plt.show()
